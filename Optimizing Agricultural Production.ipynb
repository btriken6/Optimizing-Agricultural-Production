# %% [markdown]
# ### Importing the Libraries

# %%
# for manipulations
import numpy as np
import pandas as pd

# for data visualizations
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# for interactivity
import ipywidgets
from ipywidgets import interact

# %% [markdown]
# ### Reading the Dataset

# %%
ds = pd.read_csv('data.csv')

#shape of the dataset
print("Shape of the Dataset :", ds.shape)
# Out:
# Shape of the Dataset : (2200, 8)

# %%
#head of the dataset
ds.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %% [raw]
# ## Description for each of the columns in the Dataset
#
# N - ratio of Nitrogen content in soil
# P - ratio of Phosphorous content in soil
# K - ration of Potassium content in soil
# temperature - temperature in degree Celsius
# humidity - relative humidity in %
# ph - ph value of the soil
# rainfall - rainfall in mm

# %%
#if there is any missing value present in the dataset
ds.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
#the Crops present in this Dataset
ds['label'].value_counts()
# Out:
# apple          100
# pigeonpeas     100
# banana         100
# maize          100
# blackgram      100
# grapes         100
# papaya         100
# pomegranate    100
# coconut        100
# jute           100
# chickpea       100
# orange         100
# mothbeans      100
# mungbean       100
# mango          100
# kidneybeans    100
# rice           100
# muskmelon      100
# coffee         100
# watermelon     100
# lentil         100
# cotton         100
# Name: label, dtype: int64

# %% [markdown]
# ### Descriptive Statistics

# %%
#the Summary for all the crops

print("Average Ratio of Nitrogen in the Soil : {0:.1f}".format(ds['N'].mean()))
print("Average Ratio of Phosphorous in the Soil : {0:.1f}".format(ds['P'].mean()))
print("Average Ratio of Potassium in the Soil : {0:.1f}".format(ds['K'].mean()))
print("Average Tempature in Celsius : {0:.1f}".format(ds['temperature'].mean()))
print("Average Relative Humidity in % : {0:.1f}".format(ds['humidity'].mean()))
print("Average PH Value of the soil : {0:.1f}".format(ds['ph'].mean()))
print("Average Rainfall in mm : {0:.1f}".format(ds['rainfall'].mean()))
# Out:
# Average Ratio of Nitrogen in the Soil : 50.6
# Average Ratio of Phosphorous in the Soil : 53.4
# Average Ratio of Potassium in the Soil : 48.1
# Average Tempature in Celsius : 25.6
# Average Relative Humidity in % : 71.5
# Average PH Value of the soil : 6.5
# Average Rainfall in mm : 103.5

# %%
#the Summary Statistics for each of the Crops

@interact
def summary(crops = list(ds['label'].value_counts().index)):
    x = ds[ds['label'] == crops]
    print("---------------------------------------------")
    print("Statistics for Nitrogen")
    print("Minimum Nitrigen required :", x['N'].min())
    print("Average Nitrogen required :", x['N'].mean())
    print("Maximum Nitrogen required :", x['N'].max()) 
    print("---------------------------------------------")
    print("Statistics for Phosphorous")
    print("Minimum Phosphorous required :", x['P'].min())
    print("Average Phosphorous required :", x['P'].mean())
    print("Maximum Phosphorous required :", x['P'].max()) 
    print("---------------------------------------------")
    print("Statistics for Potassium")
    print("Minimum Potassium required :", x['K'].min())
    print("Average Potassium required :", x['K'].mean())
    print("Maximum Potassium required :", x['K'].max()) 
    print("---------------------------------------------")
    print("Statistics for Temperature")
    print("Minimum Temperature required : {0:.2f}".format(x['temperature'].min()))
    print("Average Temperature required : {0:.2f}".format(x['temperature'].mean()))
    print("Maximum Temperature required : {0:.2f}".format(x['temperature'].max()))
    print("---------------------------------------------")
    print("Statistics for Humidity")
    print("Minimum Humidity required : {0:.2f}".format(x['humidity'].min()))
    print("Average Humidity required : {0:.2f}".format(x['humidity'].mean()))
    print("Maximum Humidity required : {0:.2f}".format(x['humidity'].max()))
    print("---------------------------------------------")
    print("Statistics for PH")
    print("Minimum PH required : {0:.2f}".format(x['ph'].min()))
    print("Average PH required : {0:.2f}".format(x['ph'].mean()))
    print("Maximum PH required : {0:.2f}".format(x['ph'].max()))
    print("---------------------------------------------")
    print("Statistics for Rainfall")
    print("Minimum Rainfall required : {0:.2f}".format(x['rainfall'].min()))
    print("Average Rainfall required : {0:.2f}".format(x['rainfall'].mean()))
    print("Maximum Rainfall required : {0:.2f}".format(x['rainfall'].max()))
# Out:
# interactive(children=(Dropdown(description='crops', options=('apple', 'pigeonpeas', 'banana', 'maize', 'blackg…

# %%
## Lets compare the Average Requirement for each crops with average conditions

@interact
def compare(conditions = ['N','P','K','temperature','ph','humidity','rainfall']):
    print("Average Value for", conditions,"is {0:.1f}".format(ds[conditions].mean()))
    print("----------------------------------------------")
    print("Rice : {0:.1f}".format(ds[(ds['label'] == 'rice')][conditions].mean()))
    print("Black Grams : {0:.21}".format(ds[ds['label'] == 'blackgram'][conditions].mean()))
    print("Banana : {0:.1f}".format(ds[(ds['label'] == 'banana')][conditions].mean()))
    print("Jute : {0:.1f}".format(ds[ds['label'] == 'jute'][conditions].mean()))
    print("Coconut : {0:.1f}".format(ds[(ds['label'] == 'coconut')][conditions].mean()))
    print("Apple : {0:.1f}".format(ds[ds['label'] == 'apple'][conditions].mean()))
    print("Papaya : {0:.1f}".format(ds[(ds['label'] == 'papaya')][conditions].mean()))
    print("Muskmelon : {0:.1f}".format(ds[ds['label'] == 'muskmelon'][conditions].mean()))
    print("Grapes : {0:.1f}".format(ds[(ds['label'] == 'grapes')][conditions].mean()))
    print("Watermelon : {0:.1f}".format(ds[ds['label'] == 'watermelon'][conditions].mean()))
    print("Kidney Beans: {0:.1f}".format(ds[(ds['label'] == 'kidneybeans')][conditions].mean()))
    print("Mung Beans : {0:.1f}".format(ds[ds['label'] == 'mungbean'][conditions].mean()))
    print("Oranges : {0:.1f}".format(ds[(ds['label'] == 'orange')][conditions].mean()))
    print("Chick Peas : {0:.1f}".format(ds[ds['label'] == 'chickpea'][conditions].mean()))
    print("Lentils : {0:.1f}".format(ds[(ds['label'] == 'lentil')][conditions].mean()))
    print("Cotton : {0:.1f}".format(ds[ds['label'] == 'cotton'][conditions].mean()))
    print("Maize : {0:.1f}".format(ds[(ds['label'] == 'maize')][conditions].mean()))
    print("Moth Beans : {0:.1f}".format(ds[ds['label'] == 'mothbeans'][conditions].mean()))
    print("Pigeon Peas : {0:.1f}".format(ds[(ds['label'] == 'pigeonpeas')][conditions].mean()))
    print("Mango : {0:.1f}".format(ds[ds['label'] == 'mango'][conditions].mean()))
    print("Pomegranate : {0:.1f}".format(ds[(ds['label'] == 'pomegranate')][conditions].mean()))
    print("Coffee : {0:.1f}".format(ds[ds['label'] == 'coffee'][conditions].mean()))
# Out:
# interactive(children=(Dropdown(description='conditions', options=('N', 'P', 'K', 'temperature', 'ph', 'humidit…

# %%
@interact
def compare(conditions = ['N','P','K','temperature','ph','humidity','rainfall']):
    print("Crops which require greater than the average", conditions,'\n')
    print(ds[ds[conditions] > ds[conditions].mean()]['label'].unique())
    print("----------------------------------------------")
    print("Crops which require less than the average", conditions,'\n')
    print(ds[ds[conditions] <= ds[conditions].mean()]['label'].unique())
# Out:
# interactive(children=(Dropdown(description='conditions', options=('N', 'P', 'K', 'temperature', 'ph', 'humidit…

# %% [markdown]
# ### Analyzing Agricultural Conditions

# %%
# Using Heatmap function to find the Correlation
sns.heatmap(ds.corr(),
            annot = True,
           cmap = 'copper')
plt.title('Correlation Heatmap')
plt.show()

# %%
###the distribution of different Agricultural Conditions using distplot

plt.rcParams['figure.figsize'] = (20, 10)

plt.subplot(2, 4, 1)
sns.distplot(ds['N'], color = 'yellow')
plt.xlabel('Ratio of Nitrogen', fontsize = 13)
plt.grid()

plt.subplot(2, 4, 2)
sns.distplot(ds['P'], color = 'darkblue')
plt.xlabel('Ratio of Phosphorous', fontsize = 13)
plt.grid()

plt.subplot(2, 4, 3)
sns.distplot(ds['K'], color ='skyblue')
plt.xlabel('Ratio of Potassium', fontsize = 13)
plt.grid()

plt.subplot(2, 4, 4)
sns.distplot(ds['temperature'], color = 'black')
plt.xlabel('Temperature', fontsize = 13)
plt.grid()

plt.subplot(2, 4, 5)
sns.distplot(ds['rainfall'], color = 'lightgrey')
plt.xlabel('Rainfall', fontsize = 13)
plt.grid()

plt.subplot(2, 4, 6)
sns.distplot(ds['humidity'], color = 'darkgreen')
plt.xlabel('Humidity', fontsize = 13)
plt.grid()

plt.subplot(2, 4, 7)
sns.distplot(ds['ph'], color = 'lightgreen')
plt.xlabel('pH Level', fontsize = 13)
plt.grid()

plt.suptitle('Distribution of Agricultural Conditions', fontsize = 22)
plt.show()
# Out:
# C:\Users\91700\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\91700\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
print("Some Interesting Patterns")
print("---------------------------------")
print("Crops which requires very High Ratio of Nitrogen Content :", ds[ds['N'] > 120]['label'].unique())
print("Crops which requires very High Ratio of Phosphorous Content :", ds[ds['P'] > 100]['label'].unique())
print("Crops which requires very High Ratio of Potassium Content :", ds[ds['K'] > 200]['label'].unique())
print("Crops which requires very High Rainfall:", ds[ds['rainfall'] > 200]['label'].unique())
print("Crops which requires very Low Temperature :", ds[ds['temperature'] < 10]['label'].unique())
print("Crops which requires very High Temperature :", ds[ds['temperature'] > 40]['label'].unique())
print("Crops which requires very Low Humidity:", ds[ds['humidity'] < 20]['label'].unique())
print("Crops which requires very Low pH:", ds[ds['ph'] < 4]['label'].unique())
print("Crops which requires very High pH:", ds[ds['ph'] > 9]['label'].unique())
# Out:
# Some Interesting Patterns
# ---------------------------------
# Crops which requires very High Ratio of Nitrogen Content : ['cotton']
# Crops which requires very High Ratio of Phosphorous Content : ['grapes' 'apple']
# Crops which requires very High Ratio of Potassium Content : ['grapes' 'apple']
# Crops which requires very High Rainfall: ['rice' 'papaya' 'coconut']
# Crops which requires very Low Temperature : ['grapes']
# Crops which requires very High Temperature : ['grapes' 'papaya']
# Crops which requires very Low Humidity: ['chickpea' 'kidneybeans']
# Crops which requires very Low pH: ['mothbeans']
# Crops which requires very High pH: ['mothbeans']

# %%
### which crops can only be Grown in Summer Season, Winter Season and Rainy Season

print("Summer Crops")
print(ds[(ds['temperature'] > 30) & (ds['humidity'] > 50)]['label'].unique())
print("-----------------------------------")
print("Winter Crops")
print(ds[(ds['temperature'] < 20) & (ds['humidity'] > 30)]['label'].unique())
print("-----------------------------------")
print("Rainy Crops")
print(ds[(ds['rainfall'] > 200) & (ds['humidity'] > 30)]['label'].unique())
# Out:
# Summer Crops
# ['pigeonpeas' 'mothbeans' 'blackgram' 'mango' 'grapes' 'orange' 'papaya']
# -----------------------------------
# Winter Crops
# ['maize' 'pigeonpeas' 'lentil' 'pomegranate' 'grapes' 'orange']
# -----------------------------------
# Rainy Crops
# ['rice' 'papaya' 'coconut']

# %% [markdown]
# ### Clustering Similar Crops

# %%
###Clustering these Crops

# lets import the warnings library so that we can avoid warnings
import warnings
warnings.filterwarnings('ignore')

x = ds.loc[:, ['N','P','K','temperature','ph','humidity','rainfall']].values

# let's check the shape of x
print(x.shape)

# lets convert this data into a dataframe
x_data  = pd.DataFrame(x)
x_data.head()
# Out:
# (2200, 7)
#       0     1     2          3         4          5           6
# 0  90.0  42.0  43.0  20.879744  6.502985  82.002744  202.935536
# 1  85.0  58.0  41.0  21.770462  7.038096  80.319644  226.655537
# 2  60.0  55.0  44.0  23.004459  7.840207  82.320763  263.964248
# 3  74.0  35.0  40.0  26.491096  6.980401  80.158363  242.864034
# 4  78.0  42.0  42.0  20.130175  7.628473  81.604873  262.717340

# %%
# lets determine the Optimum Number of Clusters within the Dataset

from sklearn.cluster import KMeans
plt.rcParams['figure.figsize'] = (12, 5)

wcss = []
for i in range(1, 11):
    km = KMeans(n_clusters = i, init = 'k-means++', max_iter = 200, n_init = 10, random_state = 2)
    km.fit(x)
    wcss.append(km.inertia_)

# lets plot the results
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method', fontsize = 18)
plt.xlabel('No of Cluster')
plt.ylabel('wcss')
plt.show()

# %%
#implementing the K Means algorithm to perform Clustering analysis
km = KMeans(n_clusters = 4, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
y_means = km.fit_predict(x)

# finding out the Results
a = ds['label']
y_means = pd.DataFrame(y_means)
z = pd.concat([y_means, a], axis = 1)
z = z.rename(columns = {0: 'cluster'})

#checking the Clusters of each Crops

print("Results After Applying the K Means Clustering Analysis \n")
print("Crops in First Cluster:", z[z['cluster'] == 0]['label'].unique())
print("---------------------------------------------------------------")
print("Crops in Second Cluster:", z[z['cluster'] == 1]['label'].unique())
print("---------------------------------------------------------------")
print("Crops in Third Cluster:", z[z['cluster'] == 2]['label'].unique())
print("---------------------------------------------------------------")
print("Crops in Forth Cluster:", z[z['cluster'] == 3]['label'].unique())
# Out:
# Results After Applying the K Means Clustering Analysis
#
# Crops in First Cluster: ['rice' 'pigeonpeas' 'papaya' 'coconut' 'jute' 'coffee']
# ---------------------------------------------------------------
# Crops in Second Cluster: ['maize' 'chickpea' 'kidneybeans' 'pigeonpeas' 'mothbeans' 'mungbean'
#  'blackgram' 'lentil' 'pomegranate' 'mango' 'orange' 'papaya' 'coconut']
# ---------------------------------------------------------------
# Crops in Third Cluster: ['grapes' 'apple']
# ---------------------------------------------------------------
# Crops in Forth Cluster: ['maize' 'banana' 'watermelon' 'muskmelon' 'papaya' 'cotton' 'coffee']

# %%
# Hard Clustering

print("Hard Clustering Results\n")
counts = z[z['cluster'] == 0]['label'].value_counts()
d = z.loc[z['label'].isin(counts.index[counts >= 50])]
d = d['label'].value_counts()
print("Crops in Cluster 1:", list(d.index))
print("--------------------------------------------------")
counts = z[z['cluster'] == 1]['label'].value_counts()
d = z.loc[z['label'].isin(counts.index[counts >= 50])]
d = d['label'].value_counts()
print("Crops in Cluster 2:", list(d.index))
print("--------------------------------------------------")
counts = z[z['cluster'] == 2]['label'].value_counts()
d = z.loc[z['label'].isin(counts.index[counts >= 50])]
d = d['label'].value_counts()
print("Crops in Cluster 3:", list(d.index))
print("--------------------------------------------------")
counts = z[z['cluster'] == 3]['label'].value_counts()
d = z.loc[z['label'].isin(counts.index[counts >= 50])]
d = d['label'].value_counts()
print("Crops in Cluster 4:", list(d.index))
# Out:
# Hard Clustering Results
#
# Crops in Cluster 1: ['coffee', 'rice', 'jute', 'pigeonpeas', 'coconut', 'papaya']
# --------------------------------------------------
# Crops in Cluster 2: ['mothbeans', 'orange', 'chickpea', 'lentil', 'pomegranate', 'blackgram', 'kidneybeans', 'mango', 'mungbean']
# --------------------------------------------------
# Crops in Cluster 3: ['apple', 'grapes']
# --------------------------------------------------
# Crops in Cluster 4: ['watermelon', 'maize', 'muskmelon', 'banana', 'cotton']

# %% [markdown]
# ### visualizing the Hidden Patterns

# %%
# Data Visualization

plt.rcParams['figure.figsize'] = (18, 9)

plt.subplot(2, 4, 1)
sns.barplot(ds['N'], ds['label'])
plt.ylabel(' ')
plt.xlabel('Ratio of Nitrogen', fontsize = 12)
plt.yticks(fontsize = 12)

plt.subplot(2, 4, 2)
sns.barplot(ds['P'], ds['label'])
plt.ylabel(' ')
plt.xlabel('Ratio of Phosphorous', fontsize = 12)
plt.yticks(fontsize = 12)

plt.subplot(2, 4, 3)
sns.barplot(ds['K'], ds['label'])
plt.ylabel(' ')
plt.xlabel('Ratio of Potassium', fontsize = 12)
plt.yticks(fontsize = 12)

plt.subplot(2, 4, 4)
sns.barplot(ds['temperature'], ds['label'])
plt.ylabel(' ')
plt.xlabel('Temperature', fontsize = 12)
plt.yticks(fontsize = 12)

plt.subplot(2, 4, 5)
sns.barplot(ds['humidity'], ds['label'])
plt.ylabel(' ')
plt.xlabel('Humidity', fontsize = 12)
plt.yticks(fontsize = 12)

plt.subplot(2, 4, 6)
sns.barplot(ds['ph'], ds['label'])
plt.ylabel(' ')
plt.xlabel('pH of Soil', fontsize = 12)
plt.yticks(fontsize = 12)

plt.subplot(2, 4, 7)
sns.barplot(ds['rainfall'], ds['label'])
plt.ylabel(' ')
plt.xlabel('Rainfall', fontsize = 12)
plt.yticks(fontsize = 12)

plt.suptitle('Visualizing the Impact of Different Conditions on Crops', fontsize = 16)
plt.show()

# %% [markdown]
# ### Predictive Modelling

# %%
# lets split the Dataset for Predictive Modelling

y = ds['label']
x = ds.drop(['label'], axis = 1)

print("Shape of x:", x.shape)
print("Shape of y:", y.shape)
# Out:
# Shape of x: (2200, 7)
# Shape of y: (2200,)

# %%
# lets create Training and Testing Sets for Validation of Results
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

print("The Shape of x train:", x_train.shape)
print("The Shape of x test:", x_test.shape)
print("The Shape of y train:", y_train.shape)
print("The Shape of y test:", y_test.shape)
# Out:
# The Shape of x train: (1760, 7)
# The Shape of x test: (440, 7)
# The Shape of y train: (1760,)
# The Shape of y test: (440,)

# %%
import sklearn.metrics as metrics

#LOGISTIC REGRESSION

from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

model.fit(x_train, y_train)

y_pred = model.predict(x_test)

x = metrics.accuracy_score(y_test, y_pred)

print("Accuracy is: ", x*100)
# Out:
# Accuracy is:  96.81818181818181

# %%
# lets evaluate the Model Performance
from sklearn.metrics import classification_report, confusion_matrix

#Confusion matrix
plt.rcParams['figure.figsize'] = (12, 12)
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot = True, cmap = 'Wistia')
plt.title('Confusion Matrix for Logistic Regression', fontsize = 14)
plt.show()

#Classification Report
cr = classification_report(y_test, y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        18
#       banana       1.00      1.00      1.00        18
#    blackgram       0.86      0.82      0.84        22
#     chickpea       1.00      1.00      1.00        23
#      coconut       1.00      1.00      1.00        15
#       coffee       1.00      1.00      1.00        17
#       cotton       0.89      1.00      0.94        16
#       grapes       1.00      1.00      1.00        18
#         jute       0.84      1.00      0.91        21
#  kidneybeans       1.00      1.00      1.00        20
#       lentil       0.94      0.94      0.94        17
#        maize       0.94      0.89      0.91        18
#        mango       1.00      1.00      1.00        21
#    mothbeans       0.88      0.92      0.90        25
#     mungbean       1.00      1.00      1.00        17
#    muskmelon       1.00      1.00      1.00        23
# ...

# %% [markdown]
# ### Real time Predictions

# %%
#Head of the Dataset
ds.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
# lets check the Model for Oranges also
ds[ds['label'] == 'mango'].head()
# Out:
#        N   P   K  temperature   humidity        ph   rainfall  label
# 1100   2  40  27    29.737700  47.548852  5.954627  90.095869  mango
# 1101  39  24  31    33.556956  53.729798  4.757115  98.675276  mango
# 1102  21  26  27    27.003155  47.675254  5.699587  95.851183  mango
# 1103  25  22  25    33.561502  45.535566  5.977414  95.705259  mango
# 1104   0  21  32    35.898556  54.259642  6.430139  92.197217  mango

# %%
#Real time Predictions
prediction = model.predict((np.array([[40,
                                       70,
                                       50,
                                       70,
                                       90,
                                       11.5,
                                       150]])))
print("The Suggested Crop for Given Climatic Condition is :", prediction)
# Out:
# The Suggested Crop for Given Climatic Condition is : ['mango']

# %%
#DECISION TREE

from sklearn.tree import DecisionTreeClassifier

DecisionTree = DecisionTreeClassifier(criterion='entropy',random_state=0,max_depth=5)

dt=DecisionTree.fit(x_train,y_train)

y_dt_pred = DecisionTree.predict(x_test)

x = metrics.accuracy_score(y_test, y_dt_pred)

print("DecisionTrees's Accuracy is: ", x*100)
# Out:
# DecisionTrees's Accuracy is:  92.5

# %%
plt.rcParams['figure.figsize'] = (12, 12)
cm = confusion_matrix(y_test, y_dt_pred)
sns.heatmap(cm, annot = True, cmap = 'Wistia')
plt.title('Confusion Matrix for decision tree', fontsize = 14)
plt.show()

#Classification Report also
cr = classification_report(y_test, y_dt_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        18
#       banana       1.00      1.00      1.00        18
#    blackgram       0.73      1.00      0.85        22
#     chickpea       1.00      1.00      1.00        23
#      coconut       1.00      1.00      1.00        15
#       coffee       1.00      0.82      0.90        17
#       cotton       1.00      1.00      1.00        16
#       grapes       1.00      1.00      1.00        18
#         jute       1.00      0.38      0.55        21
#  kidneybeans       1.00      0.85      0.92        20
#       lentil       0.89      1.00      0.94        17
#        maize       0.72      1.00      0.84        18
#        mango       1.00      0.90      0.95        21
#    mothbeans       1.00      0.56      0.72        25
#     mungbean       1.00      1.00      1.00        17
#    muskmelon       0.96      1.00      0.98        23
# ...

# %%
#RANDOM FOREST

from sklearn.ensemble import RandomForestClassifier

RF = RandomForestClassifier(n_estimators=20, random_state=0)

rf=RF.fit(x_train,y_train)

y_rf_pred = RF.predict(x_test)

x = metrics.accuracy_score(y_test,y_rf_pred)

print("RF's Accuracy is: ", x*100)
# Out:
# RF's Accuracy is:  99.54545454545455

# %%
plt.rcParams['figure.figsize'] = (12, 12)
cm = confusion_matrix(y_test, y_rf_pred)
sns.heatmap(cm, annot = True, cmap = 'Wistia')
plt.title('Confusion Matrix for Random Forest', fontsize = 15)
plt.show()

#Classification Report
cr = classification_report(y_test, y_rf_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        18
#       banana       1.00      1.00      1.00        18
#    blackgram       1.00      1.00      1.00        22
#     chickpea       1.00      1.00      1.00        23
#      coconut       1.00      1.00      1.00        15
#       coffee       1.00      1.00      1.00        17
#       cotton       1.00      1.00      1.00        16
#       grapes       1.00      1.00      1.00        18
#         jute       0.95      0.95      0.95        21
#  kidneybeans       1.00      1.00      1.00        20
#       lentil       1.00      1.00      1.00        17
#        maize       1.00      1.00      1.00        18
#        mango       1.00      1.00      1.00        21
#    mothbeans       1.00      1.00      1.00        25
#     mungbean       1.00      1.00      1.00        17
#    muskmelon       1.00      1.00      1.00        23
# ...

# %%
ds.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
prediction = rf.predict((np.array([[40,
                                       70,
                                       50,
                                       70,
                                       90,
                                       11.5,
                                       150]])))
print("The Suggested Crop for Given Climatic Condition is :", prediction)
# Out:
# The Suggested Crop for Given Climatic Condition is : ['papaya']

# %%
import pickle
with open("crop_yield_prediction.pkl","wb") as f:
    pickle.dump(rf, f)
